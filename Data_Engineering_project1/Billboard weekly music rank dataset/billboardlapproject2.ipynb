# %%
# import pandas
import pandas as pd
import pandas as pd
# read or import CSV file and view the data
bl = pd.read_csv('billboard.csv')
bl
# Out:
#                  artiste                                  track genre  \
# 0        Destiny's Child               Independent Women Part I  Rock
# 1                Santana                           Maria, Maria  Rock
# 2          Savage Garden                     I Knew I Loved You  Rock
# 3                Madonna                                  Music  Rock
# 4    Aguilera, Christina  Come On Over Baby (All I Want Is You)  Rock
# ..                   ...                                    ...   ...
# 312     Ghostface Killah                       Cherchez LaGhost   R&B
# 313          Smith, Will                            Freakin' It   Rap
# 314        Zombie Nation                          Kernkraft 400  Rock
# 315       Eastsidaz, The                               Got Beef   Rap
# 316               Fragma                         Toca's Miracle   R&B
#
#     date.entered date.peaked  x1st.week  x2nd.week  x3rd.week  x4th.week  \
# ...

# %%
# use melt to categorize the colmuns items under each specific column name and view the changed data
melted_bl = pd.melt(bl, id_vars=['artiste','track', 'genre','date.entered', 'date.peaked'], var_name='week'
                    , value_name='rank')
melted_bl
# Out:
#                    artiste                                  track genre  \
# 0          Destiny's Child               Independent Women Part I  Rock
# 1                  Santana                           Maria, Maria  Rock
# 2            Savage Garden                     I Knew I Loved You  Rock
# 3                  Madonna                                  Music  Rock
# 4      Aguilera, Christina  Come On Over Baby (All I Want Is You)  Rock
# ...                    ...                                    ...   ...
# 24087     Ghostface Killah                       Cherchez LaGhost   R&B
# 24088          Smith, Will                            Freakin' It   Rap
# 24089        Zombie Nation                          Kernkraft 400  Rock
# 24090       Eastsidaz, The                               Got Beef   Rap
# 24091               Fragma                         Toca's Miracle   R&B
#
#       date.entered date.peaked        week  rank
# 0       2000-09-23  2000-11-18   x1st.week  78.0
# ...

# %%
melted_bl
# Out:
#                    artiste                                  track genre  \
# 0          Destiny's Child               Independent Women Part I  Rock
# 1                  Santana                           Maria, Maria  Rock
# 2            Savage Garden                     I Knew I Loved You  Rock
# 3                  Madonna                                  Music  Rock
# 4      Aguilera, Christina  Come On Over Baby (All I Want Is You)  Rock
# ...                    ...                                    ...   ...
# 24087     Ghostface Killah                       Cherchez LaGhost   R&B
# 24088          Smith, Will                            Freakin' It   Rap
# 24089        Zombie Nation                          Kernkraft 400  Rock
# 24090       Eastsidaz, The                               Got Beef   Rap
# 24091               Fragma                         Toca's Miracle   R&B
#
#       date.entered date.peaked        week  rank
# 0       2000-09-23  2000-11-18   x1st.week  78.0
# ...

# %%
# cleaning unnecessary row and view the change
melted_bl = melted_bl.dropna()

# %%
melted_bl
# Out:
#                    artiste                                  track    genre  \
# 0          Destiny's Child               Independent Women Part I     Rock
# 1                  Santana                           Maria, Maria     Rock
# 2            Savage Garden                     I Knew I Loved You     Rock
# 3                  Madonna                                  Music     Rock
# 4      Aguilera, Christina  Come On Over Baby (All I Want Is You)     Rock
# ...                    ...                                    ...      ...
# 19663             Lonestar                                 Amazed  Country
# 19700                Creed                                 Higher     Rock
# 19980             Lonestar                                 Amazed  Country
# 20017                Creed                                 Higher     Rock
# 20334                Creed                                 Higher     Rock
#
#       date.entered date.peaked        week  rank
# ...

# %%
#extrat the weeks and convert them to integer
melted_bl['week'] = melted_bl['week'].str.extract('(\d+)').astype(int)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-30d005e454ee> in <module>
# ----> 1 melted_bl['week'] = melted_bl['week'].str.extract('(\d+)').astype(int)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5268             or name in self._accessors
#    5269         ):
# -> 5270             return object.__getattribute__(self, name)
#    5271         else:
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     185             # we're accessing the attribute of the class, i.e., Dataset.geo
#     186             return self._accessor
# --> 187         accessor_obj = self._accessor(obj)
# ...

# %%
melted_bl
# Out:
#                    artiste                                  track    genre  \
# 0          Destiny's Child               Independent Women Part I     Rock
# 1                  Santana                           Maria, Maria     Rock
# 2            Savage Garden                     I Knew I Loved You     Rock
# 3                  Madonna                                  Music     Rock
# 4      Aguilera, Christina  Come On Over Baby (All I Want Is You)     Rock
# ...                    ...                                    ...      ...
# 19663             Lonestar                                 Amazed  Country
# 19700                Creed                                 Higher     Rock
# 19980             Lonestar                                 Amazed  Country
# 20017                Creed                                 Higher     Rock
# 20334                Creed                                 Higher     Rock
#
#       date.entered date.peaked  week  rank
# ...

# %%
# substract the peaked date from the date entered to the see the number of days per ranking of the songs
melted_bl['date'] = pd.to_datetime(melted_bl['date.peaked']) - pd.to_datetime(melted_bl['date.entered'])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
# extracted date in days
melted_bl['date'].dt.days
# Out:
# 0         56
# 1         56
# 2         98
# 3         35
# 4         70
#         ...
# 19663    273
# 19700    315
# 19980    273
# 20017    315
# 20334    315
# Name: date, Length: 5307, dtype: int64

# %%
melted_bl
# Out:
#                    artiste                                  track    genre  \
# 0          Destiny's Child               Independent Women Part I     Rock
# 1                  Santana                           Maria, Maria     Rock
# 2            Savage Garden                     I Knew I Loved You     Rock
# 3                  Madonna                                  Music     Rock
# 4      Aguilera, Christina  Come On Over Baby (All I Want Is You)     Rock
# ...                    ...                                    ...      ...
# 19663             Lonestar                                 Amazed  Country
# 19700                Creed                                 Higher     Rock
# 19980             Lonestar                                 Amazed  Country
# 20017                Creed                                 Higher     Rock
# 20334                Creed                                 Higher     Rock
#
#       date.entered date.peaked  week  rank     date
# ...

# %%
# check the data type
melted_bl.dtypes
# Out:
# artiste                  object
# track                    object
# genre                    object
# date.entered             object
# date.peaked              object
# week                      int64
# rank                    float64
# date            timedelta64[ns]
# dtype: object

# %%
melted_bl
# Out:
#                    artiste                                  track    genre  \
# 0          Destiny's Child               Independent Women Part I     Rock
# 1                  Santana                           Maria, Maria     Rock
# 2            Savage Garden                     I Knew I Loved You     Rock
# 3                  Madonna                                  Music     Rock
# 4      Aguilera, Christina  Come On Over Baby (All I Want Is You)     Rock
# ...                    ...                                    ...      ...
# 19663             Lonestar                                 Amazed  Country
# 19700                Creed                                 Higher     Rock
# 19980             Lonestar                                 Amazed  Country
# 20017                Creed                                 Higher     Rock
# 20334                Creed                                 Higher     Rock
#
#       date.entered date.peaked  week  rank     date
# ...
